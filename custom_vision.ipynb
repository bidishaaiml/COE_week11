# %% [markdown]
# <a href="https://colab.research.google.com/github/bidishaaiml/COE_week11/blob/main/custom_vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python script using OpenCV to calculate and plot histograms of color channels (RGB) for an image of a natural landscape to analyze color variations and intensities.**

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
def show_image(image_path):
    # Reading the image
    image = cv2.imread(image_path)

    # Checking if the image is loaded successfully
    if image is None:
        print(f"Error: Could not load image {image_path}.")
        return None

    # Converting the image from BGR to RGB (OpenCV loads images in BGR format by default)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Displaying the image
    plt.figure(figsize=(10, 5))
    plt.imshow(image)
    plt.title('Original Image')
    plt.axis('off')  # Hiding the axis
    plt.show()

    return image

# %%
# Path to the image
image_path = '/content/download.jpg'

# Showing the image
image = show_image(image_path)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

def plot_color_histogram(image_path):
    # Reading the image
    image = cv2.imread(image_path)

    # Checking if the image is loaded successfully
    if image is None:
        print(f"Error: Could not load image {image_path}.")
        return

    # Converting the image from BGR to RGB (OpenCV loads images in BGR format by default)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Calculating histogram for each color channel
    colors = ('r', 'g', 'b')
    plt.figure(figsize=(10, 5))
    plt.title('Color Histogram')
    plt.xlabel('Pixel Value')
    plt.ylabel('Frequency')

    for i, color in enumerate(colors):
        histogram = cv2.calcHist([image], [i], None, [256], [0, 256])
        plt.plot(histogram, color=color)
        plt.xlim([0, 256])

    # Displaying the plot
    plt.show()

# Path to the image
image_path = '/content/download.jpg'

# Plotting the color histogram for the given image
plot_color_histogram(image_path)

# %%
# loading an image in grayscale mode
img = cv2.imread('/content/download.jpg',0)

# calculating frequency of pixels in range 0-255
histg = cv2.calcHist([img],[0],None,[256],[0,256])

# %%
# Using plt.imshow to display the image
plt.imshow(img, cmap='gray') # Assuming grayscale image, use cmap='gray'
plt.show()

# %%
# importing required libraries of opencv
import cv2

# importing library for plotting
from matplotlib import pyplot as plt

# reads an input image
img = cv2.imread('/content/download.jpg',0)

# finds frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])

# showing the plotting graph of an image
plt.plot(histr)
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt
img = cv2.imread('/content/download.jpg',0)


plt.hist(img.ravel(),256,[0,256])
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

def plot_histograms(image_path):
    # Reading the image
    image = cv2.imread(image_path)

    # Spliting the image into its R, G, and B components
    b, g, r = cv2.split(image)

    # Creating a figure to display the histograms
    plt.figure(figsize=(10, 5))

    # Plotting histogram for the Red channel
    plt.subplot(3, 1, 1)
    plt.hist(r.ravel(), bins=256, range=[0, 256], color='red', alpha=0.5)
    plt.title('Red Channel Histogram')
    plt.xlim([0, 256])

    # Plotting histogram for the Green channel
    plt.subplot(3, 1, 2)
    plt.hist(g.ravel(), bins=256, range=[0, 256], color='green', alpha=0.5)
    plt.title('Green Channel Histogram')
    plt.xlim([0, 256])

    # Plotting histogram for the Blue channel
    plt.subplot(3, 1, 3)
    plt.hist(b.ravel(), bins=256, range=[0, 256], color='blue', alpha=0.5)
    plt.title('Blue Channel Histogram')
    plt.xlim([0, 256])

    # Adjusting layout to avoid overlap
    plt.tight_layout()

    # Displaying the histograms
    plt.show()

# Path to the image
image_path = '/content/download.jpg'


plot_histograms(image_path)

# %%
# Path to the image
image_path = '/content/download (1).jpg'

# Showing the image
image = show_image(image_path)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

def plot_color_histogram(image_path):
    # Reading the image
    image = cv2.imread(image_path)

    # Checking if the image is loaded successfully
    if image is None:
        print(f"Error: Could not load image {image_path}.")
        return

    # Converting the image from BGR to RGB (OpenCV loads images in BGR format by default)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Calculating histogram for each color channel
    colors = ('r', 'g', 'b')
    plt.figure(figsize=(10, 5))
    plt.title('Color Histogram')
    plt.xlabel('Pixel Value')
    plt.ylabel('Frequency')

    for i, color in enumerate(colors):
        histogram = cv2.calcHist([image], [i], None, [256], [0, 256])
        plt.plot(histogram, color=color)
        plt.xlim([0, 256])

    # Displaying the plot
    plt.show()

# Path to the image
image_path = '/content/download (1).jpg'

# Ploting the color histogram for the given image
plot_color_histogram(image_path)

# %%
# loading an image in grayscale mode
img = cv2.imread('/content/download (1).jpg',0)

# calculating frequency of pixels in range 0-255
histg = cv2.calcHist([img],[0],None,[256],[0,256])

# %%
# Use plt.imshow to display the image
plt.imshow(img, cmap='gray') # Assuming grayscale image, use cmap='gray'
plt.show()

# %%
# importing required libraries of opencv
import cv2

# importing library for plotting
from matplotlib import pyplot as plt

# reads an input image
img = cv2.imread('/content/download (1).jpg',0)

# finding frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])

# showing the plotting graph of an image
plt.plot(histr)
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt
img = cv2.imread('/content/download (1).jpg',0)


plt.hist(img.ravel(),256,[0,256])
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

def plot_histograms(image_path):
    # Reading the image
    image = cv2.imread(image_path)

    # Spliting the image into its R, G, and B components
    b, g, r = cv2.split(image)

    # Creating a figure to display the histograms
    plt.figure(figsize=(10, 5))

    # Plotting histogram for the Red channel
    plt.subplot(3, 1, 1)
    plt.hist(r.ravel(), bins=256, range=[0, 256], color='red', alpha=0.5)
    plt.title('Red Channel Histogram')
    plt.xlim([0, 256])

    # Plotting histogram for the Green channel
    plt.subplot(3, 1, 2)
    plt.hist(g.ravel(), bins=256, range=[0, 256], color='green', alpha=0.5)
    plt.title('Green Channel Histogram')
    plt.xlim([0, 256])

    # Plotting histogram for the Blue channel
    plt.subplot(3, 1, 3)
    plt.hist(b.ravel(), bins=256, range=[0, 256], color='blue', alpha=0.5)
    plt.title('Blue Channel Histogram')
    plt.xlim([0, 256])

    # Adjusting layout to avoid overlap
    plt.tight_layout()

    # Displaying the histograms
    plt.show()

# Path to the image
image_path = '/content/download (1).jpg'


plot_histograms(image_path)

# %%
# Path to the image
image_path = '/content/download (2).jpg'

# Showing the image
image = show_image(image_path)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

def plot_color_histogram(image_path):
    # Reading the image
    image = cv2.imread(image_path)

    # Checking if the image is loaded successfully
    if image is None:
        print(f"Error: Could not load image {image_path}.")
        return

    # Converting the image from BGR to RGB (OpenCV loads images in BGR format by default)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Calculating histogram for each color channel
    colors = ('r', 'g', 'b')
    plt.figure(figsize=(10, 5))
    plt.title('Color Histogram')
    plt.xlabel('Pixel Value')
    plt.ylabel('Frequency')

    for i, color in enumerate(colors):
        histogram = cv2.calcHist([image], [i], None, [256], [0, 256])
        plt.plot(histogram, color=color)
        plt.xlim([0, 256])

    # Displaying the plot
    plt.show()

# Path to the image
image_path = '/content/download (2).jpg'

# Plotting the color histogram for the given image
plot_color_histogram(image_path)

# %%
# loading an image in grayscale mode
img = cv2.imread('/content/download (2).jpg',0)

# calculating frequency of pixels in range 0-255
histg = cv2.calcHist([img],[0],None,[256],[0,256])

# %%
# Using plt.imshow to display the image
plt.imshow(img, cmap='gray') # Assuming grayscale image, use cmap='gray'
plt.show()

# %%
# importing required libraries of opencv
import cv2

# importing library for plotting
from matplotlib import pyplot as plt

# reads an input image
img = cv2.imread('/content/download (2).jpg',0)

# finding frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])

# showing the plotting graph of an image
plt.plot(histr)
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt
img = cv2.imread('/content/download (2).jpg',0)


plt.hist(img.ravel(),256,[0,256])
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

def plot_histograms(image_path):
    # Reading the image
    image = cv2.imread(image_path)

    # Spliting the image into its R, G, and B components
    b, g, r = cv2.split(image)

    # Creating a figure to display the histograms
    plt.figure(figsize=(10, 5))

    # Plotting histogram for the Red channel
    plt.subplot(3, 1, 1)
    plt.hist(r.ravel(), bins=256, range=[0, 256], color='red', alpha=0.5)
    plt.title('Red Channel Histogram')
    plt.xlim([0, 256])

    # Plotting histogram for the Green channel
    plt.subplot(3, 1, 2)
    plt.hist(g.ravel(), bins=256, range=[0, 256], color='green', alpha=0.5)
    plt.title('Green Channel Histogram')
    plt.xlim([0, 256])

    # Plotting histogram for the Blue channel
    plt.subplot(3, 1, 3)
    plt.hist(b.ravel(), bins=256, range=[0, 256], color='blue', alpha=0.5)
    plt.title('Blue Channel Histogram')
    plt.xlim([0, 256])

    # Adjusting layout to avoid overlap
    plt.tight_layout()

    # Displaying the histograms
    plt.show()

# Path to the image
image_path = '/content/download (2).jpg'


plot_histograms(image_path)

# %%
# Path to the image
image_path = '/content/download (3).jpg'

# Showing the image
image = show_image(image_path)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

def plot_color_histogram(image_path):
    # Reading the image
    image = cv2.imread(image_path)

    # Checking if the image is loaded successfully
    if image is None:
        print(f"Error: Could not load image {image_path}.")
        return

    # Converting the image from BGR to RGB (OpenCV loads images in BGR format by default)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Calculating histogram for each color channel
    colors = ('r', 'g', 'b')
    plt.figure(figsize=(10, 5))
    plt.title('Color Histogram')
    plt.xlabel('Pixel Value')
    plt.ylabel('Frequency')

    for i, color in enumerate(colors):
        histogram = cv2.calcHist([image], [i], None, [256], [0, 256])
        plt.plot(histogram, color=color)
        plt.xlim([0, 256])

    # Displaying the plot
    plt.show()

# Path to the image
image_path = '/content/download (3).jpg'

# Ploting the color histogram for the given image
plot_color_histogram(image_path)

# %%
# loading an image in grayscale mode
img = cv2.imread('/content/download (3).jpg',0)

# calculating frequency of pixels in range 0-255
histg = cv2.calcHist([img],[0],None,[256],[0,256])

# %%
# Using plt.imshow to display the image
plt.imshow(img, cmap='gray') # Assuming grayscale image, use cmap='gray'
plt.show()

# %%
# importing required libraries of opencv
import cv2

# importing library for plotting
from matplotlib import pyplot as plt

# reads an input image
img = cv2.imread('/content/download (3).jpg',0)

# finding frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])

# showing the plotting graph of an image
plt.plot(histr)
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt
img = cv2.imread('/content/download (3).jpg',0)


plt.hist(img.ravel(),256,[0,256])
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

def plot_histograms(image_path):
    # Reading the image
    image = cv2.imread(image_path)

    # Spliting the image into its R, G, and B components
    b, g, r = cv2.split(image)

    # Creating a figure to display the histograms
    plt.figure(figsize=(10, 5))

    # Plotting histogram for the Red channel
    plt.subplot(3, 1, 1)
    plt.hist(r.ravel(), bins=256, range=[0, 256], color='red', alpha=0.5)
    plt.title('Red Channel Histogram')
    plt.xlim([0, 256])

    # Plotting histogram for the Green channel
    plt.subplot(3, 1, 2)
    plt.hist(g.ravel(), bins=256, range=[0, 256], color='green', alpha=0.5)
    plt.title('Green Channel Histogram')
    plt.xlim([0, 256])

    # Plotting histogram for the Blue channel
    plt.subplot(3, 1, 3)
    plt.hist(b.ravel(), bins=256, range=[0, 256], color='blue', alpha=0.5)
    plt.title('Blue Channel Histogram')
    plt.xlim([0, 256])

    # Adjusting layout to avoid overlap
    plt.tight_layout()

    # Displaying the histograms
    plt.show()

# Path to the image
image_path = '/content/download (3).jpg'


plot_histograms(image_path)

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# path to input image is specified and
# image is loaded with imread command
image1 = cv2.imread('/content/download (1).jpg')

# cv2.cvtColor is applied over the
# image input with applied parameters
# to convert the image in grayscale
img = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)

# applying different thresholding  techniques on the input image
# all pixels value above 120 will be set to 255
ret, thresh1 = cv2.threshold(img, 120, 255, cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(img, 120, 255, cv2.THRESH_BINARY_INV)
ret, thresh3 = cv2.threshold(img, 120, 255, cv2.THRESH_TRUNC)
ret, thresh4 = cv2.threshold(img, 120, 255, cv2.THRESH_TOZERO)
ret, thresh5 = cv2.threshold(img, 120, 255, cv2.THRESH_TOZERO_INV)

# the window showing output images
# with the corresponding thresholding
# techniques applied to the input images
cv2_imshow(thresh1)
cv2_imshow(thresh2)
cv2_imshow(thresh3)
cv2_imshow(thresh4)
cv2_imshow(thresh5)
# Out:
# <PIL.Image.Image image mode=L size=223x148>
# <PIL.Image.Image image mode=L size=223x148>
# <PIL.Image.Image image mode=L size=223x148>
# <PIL.Image.Image image mode=L size=223x148>
# <PIL.Image.Image image mode=L size=223x148>
